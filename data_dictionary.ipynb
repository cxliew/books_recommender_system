# %% [markdown]
# **goodreads_books.json.gz** - 2,360,655 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**isbn**|*object*|goodreads_books.json.gz|International Standard Book Number (ISBN)<br>- a numerical commercial book identifier (10 digits) before 2007|
# |**text_reviews_count**|*object*|goodreads_books.json.gz|The number of text revies given for this book|
# |**series**|*object*|goodreads_books.json.gz||
# |**country_code**|*object*|goodreads_books.json.gz|The country code this book is from|
# |**language_code**|*object*|goodreads_books.json.gz|A code representing the book language type|
# |**popular_shelves**|*object*|goodreads_books.json.gz|Popular shelves name the readers classify the book under|
# |**asin**|*object*|goodreads_books.json.gz|Amazon Standard Identification Number (ASIN) - a unique identifier of Amazon product|
# |**is_ebook**|*object*|goodreads_books.json.gz|Whether the book is an ebook|
# |**kindle_asin**|*object*|goodreads_books.json.gz|Amazon Standard Identification Number (ASIN) for kindle books|
# |**similar_books**|*object*|goodreads_books.json.gz|Id of books that are similar to the respective book|
# |**description**|*object*|goodreads_books.json.gz|A description of the book|
# |**format**|*object*|goodreads_books.json.gz|The book type|
# |**link**|*object*|goodreads_books.json.gz|The link of book in goodreads website|
# |**authors**|*object*|goodreads_books.json.gz|Id representing the author or contributor names for the book|
# |**publisher**|*object*|goodreads_books.json.gzf|The book publisher|
# |**num_pages**|*object*|goodreads_books.json.gz|The number of book pages|
# |**publication_day**|*object*|goodreads_books.json.gz|The day the book is published|
# |**isbn13**|*object*|goodreads_books.json.gz|International Standard Book Number (ISBN)<br>- a numerical commercial book identifier (13 digits) after 2007|
# |**publication_month**|*object*|goodreads_books.json.gz|The month the book is published|
# |**edition_information**|*object*|goodreads_books.json.gz|The type or information of the book edition|
# |**publication_year**|*object*|goodreads_books.json.gz|The year the book is published|
# |**url**|*object*|goodreads_books.json.gz|The url of book in goodreads website|
# |**image_url**|*object*|goodreads_books.json.gz|The url of the book image in goodreads website|
# |**book_id**|*object*|goodreads_books.json.gz|The ids of the book edition that goodreads assigned to|
# |**ratings_count**|*object*|goodreads_books.json.gz|The number of ratings given by users for the book|
# |**work_id**|*object*|goodreads_books.json.gz|The unique id of the book the goodreads assigned to|
# |**title**|*object*|goodreads_books.json.gz|The title of the book|
# |**title_without_series**|*object*|goodreads_books.json.gz|The title of the book without series|
#
# ------------------------------------
# **goodreads_authors.json.gz** - 829,529 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**average_rating**|*float64*|goodreads_authors.json.gz|An average ratings of all of the author's book ratings|
# |**author_id**|*int64*|goodreads_authors.json.gz|The ids of the author that goodreads assigned to|
# |**text_reviews_count**|*int64*|goodreads_authors.json.gz|The text reviews count of the books the author writes|
# |**name**|*object*|goodreads_authors.json.gz|The name of the author|
# |**ratings_count**|*int64*|goodreads_authors.json.gz|The total count of the ratings given to the book the author writes|
#
# ------------------------------------
# **goodreads_series.json.gz** - 400,390 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**numbered**|*int64*|goodreads_series.json.gz|Whether the book series has a chronological order<br>- true means there is, false means there isn't|
# |**note**|*int64*|goodreads_series.json.gz|Note written on additional information to take note on managing the book series list|
# |**description**|*int64*|goodreads_series.json.gz|Description of the list of book series|
# |**title**|*int64*|goodreads_series.json.gz|Title of the list of book series|
# |**series_works_count**|*int64*|goodreads_series.json.gz|The number of books listed in the book series list|
# |**series_id**|*int64*|goodreads_series.json.gz|Ids of the book series list|
# |**primary_work_count**|*int64*|goodreads_series.json.gz|The number of books listed in the book series list excluding editions|
#
# ------------------------------------
# **goodreads_book_works.json.gz** - 1,521,962 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**books_count**|*int64*|goodreads_book_works.json.gz|The number of book editions|
# |**reviews_count**|*int64*|goodreads_book_works.json.gz|The total number of reviews of all book editions|
# |**original_publication_month**|*object*|goodreads_book_works.json.gz|The publication month of the first book edition|
# |**default_description_language_code**|*object*|goodreads_book_works.json.gz|The default description of language code|
# |**text_reviews_count**|*int64*|goodreads_book_works.json.gz|The count of text reviews of the best book|
# |**best_book_id**|*int64*|goodreads_book_works.json.gz|The highest rating of all the book editions|
# |**original_publication_year**|*object*|goodreads_book_works.json.gz|The publication year of the first book edition|
# |**original_title**|*object*|goodreads_book_works.json.gz|The title of the first book edition published|
# |**rating_dist**|*object*|goodreads_book_works.json.gz|The rating distribution of the best book|
# |**default_chaptering_book_id**|*object*|goodreads_book_works.json.gz|The id of the book that is a default chaptering|
# |**original_publication_day**|*object*|goodreads_book_works.json.gz|The publication day of the first book edition|
# |**original_language_id**|*object*|goodreads_book_works.json.gz|The language id of the first book edition|
# |**ratings_count**|*int64*|goodreads_book_works.json.gz|The count of ratings given for the best book|
# |**media_type**|*object*|goodreads_book_works.json.gz|The book type|
# |**ratings_sum**|*int64*|goodreads_book_works.json.gz|The sum of the (number of ratings given x rating)|
# |**work_id**|*int64*|goodreads_book_works.json.gz|The unique id of the book the goodreads assigned to|
#
# ------------------------------------
# **goodreads_genres_initial.json.gz** - 2,360,655 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**book_id**|*int64*|goodreads_genres_initial.json.gz|The ids of the book edition that goodreads assigned to|
# |**genres**|*object*|goodreads_genres_initial.json.gz|The genres of the book|
#
# -----------------------------------------
#
# **goodreads_interactions.csv** - 228,648,342 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**user_id**|*int64*|goodreads_interactions.csv|An assigned id of the user|
# |**book_id**|*int64*|goodreads_interactions.csv|An assigned id of the book|
# |**is_read**|*int64*|goodreads_interactions.csv|Whether the user read the book.<br>0 is not read, 1 is read|
# |**rating**|*int64*|goodreads_interactions.csv|The rating of a book the user read - a range of 1 to 5<br>- 1 : disliked, to 5 : loved it and an amazing read|
# |**is_reviewed**|*int64*|goodreads_interactions.csv|Whether the user reviewed the book.<br>0 is not reviewed, 1 is reviewed|
#
# ------------------------------------
# **book_id_map.csv** - 2,360,650 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**book_id_csv**|*int64*|book_id_map.csv|An assigned id of the book|
# |**book_id**|*int64*|book_id_map.csv|The ids of the book edition that goodreads assigned to|
