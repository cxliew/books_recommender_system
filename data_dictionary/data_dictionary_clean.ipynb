# %% [markdown]
# **booklist_compiled** - 2,360,131 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**text_reviews_count**|*int32*|booklist_compiled|The number of text revies given for this book|
# |**series**|*int64*|booklist_compiled|The series number the book is in|
# |**language_code**|*object*|booklist_compiled|A code representing the book language type|
# |**asin**|*int64*|booklist_compiled|Amazon Standard Identification Number (ASIN) - a unique identifier of Amazon product<br>- 1 means it has, 0 means it doesn't have|
# |**is_ebook**|*int64*|booklist_compiled|Whether the book is an ebook.<br>- 1 means it is, 0 means it isn't|
# |**average_rating**|*float64*|booklist_compiled|The average ratings for the book|
# |**kindle_asin**|*int64*|booklist_compiled|Amazon Standard Identification Number (ASIN) for kindle books<br>- 1 means it has, 0 means it doesn't have|
# |**description**|*object*|booklist_compiled|A description of the book|
# |**format**|*object*|booklist_compiled|The book type|
# |**publisher**|*object*|booklist_compiled|The book publisher|
# |**num_pages**|*object*|booklist_compiled|The number of book pages|
# |**edition_information**|*object*|booklist_compiled|The type or information of the book edition|
# |**publication_year**|*object*|booklist_compiled|The year the book is published|
# |**book_id**|*int32*|booklist_compiled|The ids of the book edition that goodreads assigned to|
# |**ratings_count**|*int32*|booklist_compiled|The number of ratings given by users for the book|
# |**work_id**|*int32*|booklist_compiled|The unique id of the book the goodreads assigned to|
# |**title**|*object*|booklist_compiled|The title of the book|
# |**author_name**|*object*|booklist_compiled|The first author name of the book|
# |**first_author_title**|*object*|booklist_compiled|The first author name and the title of the book|
#
# ------------------------------------
# **multiple_authors_name_df** - 3,323,621 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**work_id**|*int64*|multiple_authors_name_df|The unique id of the book the goodreads assigned to|
# |**book_id**|*int64*|multiple_authors_name_df|The ids of the book edition that goodreads assigned to|
# |**title**|*object*|multiple_authors_name_df|The title of the book|
# |**author_id**|*int32*|multiple_authors_name_df|The ids of the author that goodreads assigned to|
# |**role**|*object*|multiple_authors_name_df|The role of the authors of the book|
# |**author_name**|*object*|multiple_authors_name_df|The author name of the book|
#
# ------------------------------------
# **series_list_df** - 822,460 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**work_id**|*int64*|series_list_df|The unique id of the book the goodreads assigned to|
# |**book_id**|*int64*|series_list_df|The ids of the book edition that goodreads assigned to|
# |**series**|*int32*|series_list_df|The series number which this book is in|
#
# ------------------------------------
# **similar_books_list_df** - 16,809,717 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**book_id**|*int64*|similar_books_list_df|The ids of the book edition that goodreads assigned to|
# |**similar_books**|*int32*|similar_books_list_df|Id of books that are similar to the respective book|
# |**work_id**|*int32*|similar_books_list_df|The unique id of the book the goodreads assigned to|
#
# ------------------------------------
# **booklist_authors** - 829,529 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**average_rating**|*float64*|booklist_authors|An average ratings of all of the author's book ratings|
# |**author_id**|*int64*|booklist_authors|The ids of the author that goodreads assigned to|
# |**text_reviews_count**|*int64*|booklist_authors|The text reviews count of the books the author writes|
# |**author_name**|*object*|booklist_authors|The name of the author|
# |**ratings_count**|*int64*|booklist_authors|The total count of the ratings given to the book the author writes|
#
# ------------------------------------
# **authors_list** - 829,529 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**author_id**|*int64*|authors_list|The ids of the author that goodreads assigned to|
# |**author_name**|*object*|authors_list|The name of the author|
#
# ------------------------------------
# **bookid_removed** - 524 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**book_id**|*int32*|bookid_removed|The ids of the book edition that goodreads assigned to that have been removed from the booklist_compiled|
#
# ------------------------------------
# **booklist_url** - 1,521,962 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**url**|*object*|booklist_url|The url of book in goodreads website|
# |**image_url**|*object*|booklist_url|The url of the book image in goodreads website|
# |**work_id**|*int64*|booklist_url|The unique id of the book the goodreads assigned to|
# |**first_author_title**|*object*|booklist_url|The first author name and the title of the book|
# |**title**|*object*|booklist_url|The title of the book|
# |**first_author_name**|*object*|booklist_url|The first author name of the book|
#
# ------------------------------------
# **booklist_works** - 1,521,962 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**books_count**|*int64*|booklist_works|The number of book editions|
# |**reviews_count**|*int64*|booklist_works|The total number of reviews of all book editions|
# |**text_reviews_count**|*int64*|booklist_works|The count of text reviews of the best book|
# |**best_book_id**|*int64*|booklist_works|The highest rating of all the book editions|
# |**original_publication_year**|*object*|booklist_works|The publication year of the first book edition|
# |**rating_dist**|*object*|booklist_works|The rating distribution of the best book|
# |**ratings_count**|*int64*|booklist_works|The count of ratings given for the best book|
# |**media_type**|*object*|booklist_works|The book type|
# |**ratings_sum**|*int64*|booklist_works|The sum of the (number of ratings given x rating)|
# |**work_id**|*int64*|booklist_works|The unique id of the book the goodreads assigned to|
# |**average_rating**|*float64*|booklist_works|The average ratings for the book|
# |**title**|*object*|booklist_works|The title of the first book edition published|
# |**author_name**|*object*|booklist_works|The first author name of the book|
# |**first_author_title**|*object*|booklist_works|The first author name and the title of the book|
#
# ------------------------------------
# **booklist_genres** - 1,125,882 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**children**|*float64*|booklist_genres|The number of users classify the book under children genre|
# |**comics, graphic**|*float64*|booklist_genres|The number of users classify the book under comics, graphic genre|
# |**fantasy, paranormal**|*float64*|booklist_genres|The number of users classify the book under fantasy, paranormal genre|
# |**fiction**|*float64*|booklist_genres|The number of users classify the book under fiction genre|
# |**history, historical fiction, biography**|*float64*|booklist_genres|The number of users classify the book under history, historical fiction, biography genre|
# |**mystery, thriller, crime**|*float64*|booklist_genres|The number of users classify the book under mystery, thriller, crime genre|
# |**non-fiction**|*float64*|booklist_genres|The number of users classify the book under non-fiction genre|
# |**poetry**|*float64*|booklist_genres|The number of users classify the book under poetry genre|
# |**romance**|*float64*|booklist_genres|The number of users classify the book under romance genre|
# |**young-adult**|*float64*|booklist_genres|The number of users classify the book under young-adult genre|
# |**work_id**|*int32*|booklist_genres|The unique id of the book the goodreads assigned to|
#
# ------------------------------------
# **booklist_series** - 400,390 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**numbered**|*int64*|booklist_series|Whether the book series has a chronological order<br>- 1 means there is, 0 means there isn't|
# |**title**|*object*|booklist_series|Title of the list of book series|
# |**series_works_count**|*int64*|booklist_series|The number of books listed in the book series list|
# |**series_id**|*int64*|booklist_series|Ids of the book series list|
# |**primary_work_count**|*int64*|booklist_series|The number of books listed in the book series list excluding editions|
#
# -----------------------------------------
#
# **booklist_interactions** - 104,543,831 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**user_id**|*int64*|booklist_interactions|An assigned id of the user|
# |**book_id**|*int64*|booklist_interactions|An assigned id of the book|
# |**is_read**|*int64*|booklist_interactions|Whether the user read the book.<br>0 is not read, 1 is read|
# |**rating**|*int64*|booklist_interactions|The rating of a book the user read - a range of 1 to 5<br>- 1 : disliked, to 5 : loved it and an amazing read|
# |**is_reviewed**|*int64*|booklist_interactions|Whether the user reviewed the book.<br>0 is not reviewed, 1 is reviewed|
# |**work_id**|*int32*|booklist_interactions|The unique id of the book the goodreads assigned to|
#
# ------------------------------------
# **book_work_csv_id** - 2,360,131 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**book_id**|*int32*|book_work_csv_id|The ids of the book edition that goodreads assigned to|
# |**work_id**|*int32*|book_work_csv_id|The unique id of the book the goodreads assigned to|
# |**book_id_csv**|*int64*|book_work_csv_id|An assigned id of the book|
#
# ------------------------------------
# **user_work_interactions** - 104,021,211 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**user_id**|*int64*|user_work_interactions|An assigned id of the user|
# |**work_id**|*int64*|user_work_interactions|The unique id of the book the goodreads assigned to|
# |**rating**|*float64*|user_work_interactions|The average rating of a book the user read - a range of 1 to 5<br>- 1 : disliked, to 5 : loved it and an amazing read|
#
# ------------------------------------
# **genrebook_interactions** - 1,117,435 entries
#
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**children**|*float64*|booklist_genres|The number of users classify the book under children genre|
# |**comics, graphic**|*float64*|booklist_genres|The number of users classify the book under comics, graphic genre|
# |**fantasy, paranormal**|*float64*|booklist_genres|The number of users classify the book under fantasy, paranormal genre|
# |**fiction**|*float64*|booklist_genres|The number of users classify the book under fiction genre|
# |**history, historical fiction, biography**|*float64*|booklist_genres|The number of users classify the book under history, historical fiction, biography genre|
# |**mystery, thriller, crime**|*float64*|booklist_genres|The number of users classify the book under mystery, thriller, crime genre|
# |**non-fiction**|*float64*|booklist_genres|The number of users classify the book under non-fiction genre|
# |**poetry**|*float64*|booklist_genres|The number of users classify the book under poetry genre|
# |**romance**|*float64*|booklist_genres|The number of users classify the book under romance genre|
# |**young-adult**|*float64*|booklist_genres|The number of users classify the book under young-adult genre|
